# %% [markdown]
# # Método de Riemann

# %%
function Riemann(f,a,b,n)
    list = linspace(a,b,n)
    I = 0
    for i in 1:length(list)-1
        a = list[i]
        b = list[i+1]
        I += (b-a)*f((a+b)/2)
    end
    return I
end
# Out:
# Riemann (generic function with 1 method)

# %%
Riemann(x->x^2,1,3,100)
# Out:
# 8.66659864639663

# %%
function Trapecio(f,a,b,n)
    list = linspace(a,b,n)
    I = 0
    for i in 1:length(list)-1
        a = list[i]
        b = list[i+1]
        I += (b-a)*(f(a)+f(b))/2
    end
    return I
end
# Out:
# Trapecio (generic function with 1 method)

# %%
Trapecio(x->x^2,1,3,100)
# Out:
# 8.666802707206749

# %%
function Simpson(f,a,b,n)
    list = linspace(a,b,n)
    I = 0
    for i in 1:length(list)-1
        a = list[i]
        b = list[i+1]
        I += (b-a)*(f(a)+4*f((a+b)/2)+f(b))/6
    end
    return I
end
# Out:
# Simpson (generic function with 1 method)

# %%
Simpson(x->x^2,1,3,100)
# Out:
# 8.666666666666668

# %%
division = range(5,5,4)
# Out:
# 5:5:20

# %%
list1 = zeros(length(division))
for i in 1:length(division)
    list1[i] = Riemann(x->cos.(x)+1,-pi,pi,division[i])
end

# %%
error1 = abs.((list1-2*pi)/2*pi);

# %%
list2 = zeros(length(division))
for i in 1:length(division)
    list2[i] = Trapecio(x->cos.(x)+1,-pi,pi,division[i])
end

# %%
error2 = abs.((list2-2*pi)/2*pi);

# %%
list3 = zeros(length(division))
for i in 1:length(division)
    list3[i] = Simpson(x->cos.(x)+1,-pi,pi,division[i])
end

# %%
error3 = abs.((list3-2*pi)/2*pi);

# %%
using PyPlot

# %%
plot(error1,label="Riemann")
plot(error2,label="Trapecio")
plot(error3,label="Simpson")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f0977962710>)
# PyObject <matplotlib.legend.Legend object at 0x7f09738e3940>

# %%
list1
# Out:
# 11-element Array{Float64,1}:
#  6.28319
#  6.28319
#  6.28319
#  6.28319
#  6.28319
#  6.28319
#  6.28319
#  6.28319
#  6.28319
#  6.28319
#  6.28319

# %%
2*pi
# Out:
# 6.283185307179586

# %%
list1[2]-2*pi
# Out:
# -8.881784197001252e-16
