# %% [markdown]
# # Graficación de histogramas y estadistica básica

# %%
listatotal=[6.75,2,4,3.25,7.75,5,0,1.25,3,1.5,2,5.25,7,1.5,3,0,9,2.5,0.75,8,3.5,4.5,
    1.625,3,2,6.5,5,7.5,2,3.5,2.75,4.75,5,2.25];
listabiomedicas=[3.25,3,2,9,2.5,3.5,3,2,2,3.5,4.75];
listfisica=[6.75,2,4,7.75,5,0,1.25,1.5,5.25,7,1.5,3,0,0.75,4.5,1.625,6.5,5,7.5,2.75,2.25];

# %%
[length(listatotal),length(listabiomedicas),length(listfisica)]
# Out:
# 3-element Array{Int64,1}:
#  34
#  11
#  21

# %%
using PyPlot
# Out:
# INFO: Installing PyQt5 via Anaconda's /home/david/anaconda3/bin/conda...
# Fetching package metadata .........
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /home/david/anaconda3:
# #
# pyqt                      4.11.4                   py34_4

# %%
plt[:figure]()
plt[:hist](listatotal)
plt[:xlabel]("Calificación")
plt[:ylabel]("# de Alumnos")
plt[:show]()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f7e9d61d9b0>)

# %%
plt[:figure]()
plt[:hist](listabiomedicas)
plt[:xlabel]("Calificación")
plt[:ylabel]("# de Alumnos")
plt[:title]("Biomédicas")
plt[:show]()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f7e9aae7d68>)

# %%
plt[:figure]()
plt[:hist](listfisica)
plt[:xlabel]("Calificación")
plt[:ylabel]("# de Alumnos")
plt[:title]("Física")
plt[:show]()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f7e9aa6ce48>)

# %%
mean(listatotal)
# Out:
# 3.7463235294117645

# %%
mean(listfisica)
# Out:
# 3.613095238095238

# %%
mean(listabiomedicas)
# Out:
# 3.5
